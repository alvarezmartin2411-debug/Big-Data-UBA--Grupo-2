# %% [markdown]
# **MAESTRÍA EN ECONOMÍA APLICADA - UBA 2025**
# **TALLER DE PROGRAMACIÓN**
# **GRUPO 2**

# %% [markdown]
# # PROYECTO FINAL: TALLER DE PROGRAMACIÓN

# %%
# En caso no contar con las librerías, instalar con el siguiente cod
# !pip install pandas numpy scipy scikit-learn tslearn hdbscan matplotlib seaborn geopandas folium plotly openpyxl tqdm

# %% [markdown]
# ### 1) IMPORTS + CONFIGURACIÓN GENERAL

# %%
import os, glob, warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
from datetime import datetime
from tqdm import tqdm

# Preproc y ML
from sklearn.preprocessing import StandardScaler
from sklearn.impute import KNNImputer
from sklearn.metrics import silhouette_score
from scipy import stats
from pathlib import Path

# DTW / clustering
from tslearn.clustering import TimeSeriesKMeans
from tslearn.metrics import cdist_dtw

# Visualización
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")

# %%
# BASE_PATH = r"C:\Users\marti\Downloads\Bases"  # ajustá si hace falta
BASE_PATH = Path(r"D:\Maestría UBA\Semestre 5\Taller de programacion\Bases")
START_YEAR = 2019
END_YEAR = 2025

# %%
for year in range(START_YEAR, END_YEAR + 1):
    year_path = BASE_PATH / str(year)
    if not year_path.is_dir():
        print(f"⚠️ Carpeta año {year} no existe, se salta.")
        continue

    # Buscar carpetas tipo StockArgenprop_*
    for carpeta in year_path.glob("StockArgenprop_*"):
        if not carpeta.is_dir():
            continue

        # Rutas relevantes
        parquet_file = carpeta / "StockArgenprop.parquet"

        # 🔍 Si ya existe parquet → saltar carpeta
        if parquet_file.exists():
            print(f"⏩ Parquet ya existe, se ignora: {parquet_file}")
            continue

        # Buscar Excel
        xlsx_files = list(carpeta.glob("StockArgenprop*.xlsx"))
        if not xlsx_files:
            print(f"⚠️ No se encontró StockArgenprop*.xlsx en {carpeta}")
            continue

        excel_file = xlsx_files[0]

        print(f"📂 Leyendo Excel: {excel_file}")
        try:
            df = pd.read_excel(excel_file, engine="openpyxl")
        except Exception as e:
            print(f"❌ Error leyendo {excel_file}: {e}")
            continue

        print(f"   📊 Excel leído correctamente: {df.shape[0]} filas.")

        print(f"💾 Guardando como parquet: {parquet_file}")
        try:
            df.to_parquet(parquet_file, index=False)
            print("   ✅ Parquet generado correctamente.\n")
        except Exception as e:
            print(f"   ❌ Error guardando parquet: {e}\n")
# Out:
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2019\StockArgenprop_2019-01-31\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2019\StockArgenprop_2019-02-28\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2019\StockArgenprop_2019-03-31\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2019\StockArgenprop_2019-04-30\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2019\StockArgenprop_2019-05-31\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2019\StockArgenprop_2019-06-30\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2019\StockArgenprop_2019-07-31\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2019\StockArgenprop_2019-08-31\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2019\StockArgenprop_2019-09-30\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2019\StockArgenprop_2019-10-31\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2019\StockArgenprop_2019-11-30\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2019\StockArgenprop_2019-12-31\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2020\StockArgenprop_2020-01-31\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2020\StockArgenprop_2020-02-29\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2020\StockArgenprop_2020-03-31\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2020\StockArgenprop_2020-04-30\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2020\StockArgenprop_2020-05-31\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2020\StockArgenprop_2020-06-30\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2020\StockArgenprop_2020-07-31\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2020\StockArgenprop_2020-08-31\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2020\StockArgenprop_2020-09-30\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2020\StockArgenprop_2020-10-31\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2020\StockArgenprop_2020-11-30\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2020\StockArgenprop_2020-12-31\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2021\StockArgenprop_2021-01-31\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2021\StockArgenprop_2021-02-28\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2021\StockArgenprop_2021-03-31\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2021\StockArgenprop_2021-04-30\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2021\StockArgenprop_2021-05-31\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2021\StockArgenprop_2021-06-30\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2021\StockArgenprop_2021-07-31\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2021\StockArgenprop_2021-08-31\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2021\StockArgenprop_2021-09-30\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2021\StockArgenprop_2021-10-31\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2021\StockArgenprop_2021-11-30\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2021\StockArgenprop_2021-12-31\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2022\StockArgenprop_2022-01-31\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2022\StockArgenprop_2022-02-28\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2022\StockArgenprop_2022-03-31\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2022\StockArgenprop_2022-04-30\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2022\StockArgenprop_2022-05-31\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2022\StockArgenprop_2022-06-30\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2022\StockArgenprop_2022-07-31\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2022\StockArgenprop_2022-08-31\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2022\StockArgenprop_2022-09-30\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2022\StockArgenprop_2022-10-31\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2022\StockArgenprop_2022-11-30\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2022\StockArgenprop_2022-12-31\StockArgenprop.parquet
# ⚠️ No se encontró StockArgenprop*.xlsx en D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2023\StockArgenprop_2023-01-31
# ⚠️ No se encontró StockArgenprop*.xlsx en D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2023\StockArgenprop_2023-02-28
# ⚠️ No se encontró StockArgenprop*.xlsx en D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2023\StockArgenprop_2023-03-31
# ⚠️ No se encontró StockArgenprop*.xlsx en D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2023\StockArgenprop_2023-04-30
# ⚠️ No se encontró StockArgenprop*.xlsx en D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2023\StockArgenprop_2023-05-31
# ⚠️ No se encontró StockArgenprop*.xlsx en D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2023\StockArgenprop_2023-06-30
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2023\StockArgenprop_2023-07-31\StockArgenprop.parquet
# ⚠️ No se encontró StockArgenprop*.xlsx en D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2023\StockArgenprop_2023-08-31
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2023\StockArgenprop_2023-09-30\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2023\StockArgenprop_2023-10-31\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2023\StockArgenprop_2023-11-30\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2023\StockArgenprop_2023-12-31\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2024\StockArgenprop_2024-01-31\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2024\StockArgenprop_2024-02-29\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2024\StockArgenprop_2024-03-31\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2024\StockArgenprop_2024-04-30\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2024\StockArgenprop_2024-05-31\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2024\StockArgenprop_2024-06-30\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2024\StockArgenprop_2024-07-31\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2024\StockArgenprop_2024-08-31\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2024\StockArgenprop_2024-09-30\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2024\StockArgenprop_2024-10-31\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2024\StockArgenprop_2024-11-30\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2024\StockArgenprop_2024-12-31\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2025\StockArgenprop_2025-01-31\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2025\StockArgenprop_2025-02-28\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2025\StockArgenprop_2025-03-31\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2025\StockArgenprop_2025-04-30\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2025\StockArgenprop_2025-05-31\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2025\StockArgenprop_2025-06-30\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2025\StockArgenprop_2025-07-31\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2025\StockArgenprop_2025-08-31\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2025\StockArgenprop_2025-09-30\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2025\StockArgenprop_2025-10-31\StockArgenprop.parquet

# %% [markdown]
# ### 2) FUNCIONES PARA CARGA DE BASES MENSUALES

# %%
dfs = []

for year in range(START_YEAR, END_YEAR + 1):
    year_path = BASE_PATH / str(year)
    if not year_path.is_dir():
        continue

    for carpeta in year_path.glob("StockArgenprop_*"):
        parquet_file = carpeta / "StockArgenprop.parquet"
        if parquet_file.is_file():
            print(f"📂 Leyendo parquet: {parquet_file}")
            df = pd.read_parquet(parquet_file)
            df["ArchivoOrigen"] = parquet_file.name
            dfs.append(df)

if not dfs:
    raise ValueError("No se encontraron archivos parquet. Ejecuta primero la conversión de Excel.")

df_raw = pd.concat(dfs, ignore_index=True)
print("📊 Total archivos cargados:", len(dfs))
print("📊 Total filas concatenadas:", df_raw.shape[0])
# Out:
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2019\StockArgenprop_2019-01-31\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2019\StockArgenprop_2019-02-28\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2019\StockArgenprop_2019-03-31\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2019\StockArgenprop_2019-04-30\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2019\StockArgenprop_2019-05-31\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2019\StockArgenprop_2019-06-30\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2019\StockArgenprop_2019-07-31\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2019\StockArgenprop_2019-08-31\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2019\StockArgenprop_2019-09-30\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2019\StockArgenprop_2019-10-31\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2019\StockArgenprop_2019-11-30\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2019\StockArgenprop_2019-12-31\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2020\StockArgenprop_2020-01-31\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2020\StockArgenprop_2020-02-29\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2020\StockArgenprop_2020-03-31\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2020\StockArgenprop_2020-04-30\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2020\StockArgenprop_2020-05-31\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2020\StockArgenprop_2020-06-30\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2020\StockArgenprop_2020-07-31\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2020\StockArgenprop_2020-08-31\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2020\StockArgenprop_2020-09-30\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2020\StockArgenprop_2020-10-31\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2020\StockArgenprop_2020-11-30\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2020\StockArgenprop_2020-12-31\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2021\StockArgenprop_2021-01-31\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2021\StockArgenprop_2021-02-28\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2021\StockArgenprop_2021-03-31\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2021\StockArgenprop_2021-04-30\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2021\StockArgenprop_2021-05-31\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2021\StockArgenprop_2021-06-30\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2021\StockArgenprop_2021-07-31\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2021\StockArgenprop_2021-08-31\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2021\StockArgenprop_2021-09-30\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2021\StockArgenprop_2021-10-31\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2021\StockArgenprop_2021-11-30\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2021\StockArgenprop_2021-12-31\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2022\StockArgenprop_2022-01-31\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2022\StockArgenprop_2022-02-28\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2022\StockArgenprop_2022-03-31\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2022\StockArgenprop_2022-04-30\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2022\StockArgenprop_2022-05-31\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2022\StockArgenprop_2022-06-30\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2022\StockArgenprop_2022-07-31\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2022\StockArgenprop_2022-08-31\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2022\StockArgenprop_2022-09-30\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2022\StockArgenprop_2022-10-31\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2022\StockArgenprop_2022-11-30\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2022\StockArgenprop_2022-12-31\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2023\StockArgenprop_2023-07-31\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2023\StockArgenprop_2023-09-30\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2023\StockArgenprop_2023-10-31\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2023\StockArgenprop_2023-11-30\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2023\StockArgenprop_2023-12-31\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2024\StockArgenprop_2024-01-31\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2024\StockArgenprop_2024-02-29\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2024\StockArgenprop_2024-03-31\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2024\StockArgenprop_2024-04-30\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2024\StockArgenprop_2024-05-31\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2024\StockArgenprop_2024-06-30\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2024\StockArgenprop_2024-07-31\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2024\StockArgenprop_2024-08-31\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2024\StockArgenprop_2024-09-30\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2024\StockArgenprop_2024-10-31\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2024\StockArgenprop_2024-11-30\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2024\StockArgenprop_2024-12-31\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2025\StockArgenprop_2025-01-31\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2025\StockArgenprop_2025-02-28\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2025\StockArgenprop_2025-03-31\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2025\StockArgenprop_2025-04-30\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2025\StockArgenprop_2025-05-31\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2025\StockArgenprop_2025-06-30\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2025\StockArgenprop_2025-07-31\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2025\StockArgenprop_2025-08-31\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2025\StockArgenprop_2025-09-30\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2025\StockArgenprop_2025-10-31\StockArgenprop.parquet
# 📊 Total archivos cargados: 75
# 📊 Total filas concatenadas: 34485350

# %% [markdown]
# ### 3) LIMPIEZA + GENERACIÓN DE VARIABLES

# %%
def limpiar_y_generar(df: pd.DataFrame) -> pd.DataFrame:
    """
    Limpia y enriquece el DataFrame de propiedades:
    - Normaliza nombres de columnas (strip).
    - Asegura tipos de fechas y numéricos (solo cuando hace falta).
    - Crea columna 'month' usando FechaModificacion (fallback FechaPublicacion).
    - Crea 'superficie_ref' y 'precio_m2'.
    - Normaliza 'Codigo' como string.

    ⚠️ Modifica el DataFrame EN EL LUGAR (in-place) y lo devuelve.
    """

    # 1) Normalizar nombres de columnas (quitar espacios al inicio/fin)
    cols_map = {c: c.strip() for c in df.columns}
    df.rename(columns=cols_map, inplace=True)

    # 2) Fechas: solo convertir si no son datetime64[ns]
    for col in ["FechaPublicacion", "FechaModificacion"]:
        if col in df.columns and not np.issubdtype(df[col].dtype, np.datetime64):
            df[col] = pd.to_datetime(df[col], errors="coerce")

    # 3) month: usar FechaModificacion cuando exista, si no FechaPublicacion
    if "FechaModificacion" in df.columns and "FechaPublicacion" in df.columns:
        # Preferimos FechaModificacion; si es NaN, usamos FechaPublicacion
        base_fecha = df["FechaModificacion"].fillna(df["FechaPublicacion"])
        df["month"] = base_fecha.dt.to_period("M")
    elif "FechaModificacion" in df.columns:
        df["month"] = df["FechaModificacion"].dt.to_period("M")
    elif "FechaPublicacion" in df.columns:
        df["month"] = df["FechaPublicacion"].dt.to_period("M")
    else:
        # No debería pasar en tu df_raw, pero por seguridad:
        df["month"] = pd.PeriodIndex([pd.NaT] * len(df), freq="M")

    # 4) Variables numéricas: solo si la columna existe y no es ya numérica
    num_cols = [
        "MontoOperacion", "PropiedadSuperficieTotal", "SuperficieCubierta",
        "SuperficieDescubierta", "CantidadAmbientes", "CantidadDormitorios",
        "Antiguedad", "DepartamentoExpensas", "CantidadCocheras",
        "Latitud", "Longitud"
    ]
    for c in num_cols:
        if c in df.columns and not np.issubdtype(df[c].dtype, np.number):
            df[c] = pd.to_numeric(df[c], errors="coerce")

    # 5) superficie_ref = PropiedadSuperficieTotal; si NaN, usar SuperficieCubierta
    if "PropiedadSuperficieTotal" in df.columns and "SuperficieCubierta" in df.columns:
        df["superficie_ref"] = df["PropiedadSuperficieTotal"].where(
            df["PropiedadSuperficieTotal"].notna(),
            df["SuperficieCubierta"]
        )
    elif "PropiedadSuperficieTotal" in df.columns:
        df["superficie_ref"] = df["PropiedadSuperficieTotal"]
    elif "SuperficieCubierta" in df.columns:
        df["superficie_ref"] = df["SuperficieCubierta"]
    else:
        df["superficie_ref"] = np.nan  # fallback extremo

    # 6) precio_m2 = MontoOperacion / superficie_ref
    if "MontoOperacion" in df.columns:
        df["precio_m2"] = df["MontoOperacion"] / df["superficie_ref"]
        # NaN para casos inválidos o superficie <= 0
        df.loc[(df["superficie_ref"] <= 0) | (df["precio_m2"] <= 0), "precio_m2"] = np.nan
    else:
        df["precio_m2"] = np.nan

    # 7) Normalizar Codigo como string
    if "Codigo" in df.columns:
        df["Codigo"] = df["Codigo"].astype(str)

    return df

# Uso:
df = limpiar_y_generar(df_raw)

# %% [markdown]
# ### 4. ESTADÍSTICA DESCRIPTIVA

# %%
# Estadística básica global
desc_global = df[["MontoOperacion","superficie_ref","precio_m2","CantidadAmbientes","CantidadDormitorios"]].describe().T
desc_global["missing_pct"] = df[["MontoOperacion","superficie_ref","precio_m2","CantidadAmbientes","CantidadDormitorios"]].isna().mean().values
desc_global

# Conteos por mes (tamaño de muestra mensual)
conteo_mes = df.groupby("month").size().rename("n_obs").reset_index()
conteo_mes.head()

# Distribución por TipoPropiedad y TipoOperacion
if "TipoPropiedad" in df.columns:
    tipo_prop_counts = df["TipoPropiedad"].value_counts().reset_index().rename(columns={"index":"TipoPropiedad","TipoPropiedad":"count"})
else:
    tipo_prop_counts = pd.DataFrame()

# Precio_m2 por barrio (top 20)
if "Barrio" in df.columns:
    precio_barrio = df.groupby("Barrio")["precio_m2"].median().dropna().sort_values(ascending=False).head(20)
else:
    precio_barrio = pd.Series()

# %%
desc_global.to_csv("desc_global.csv")
conteo_mes.to_csv("conteo_mes.csv", index=False)
precio_barrio.to_csv("precio_barrio_top20.csv")

# %% [markdown]
# ### 5. CONSTRUIR PANEL MENSUAL

# %%
# 1) Filtrar periodo seleccionado (ejemplo 2019-01 en adelante)
df = df[df["month"].notna()]
df = df[df["month"] >= pd.Period(f"{START_YEAR}-01", freq="M")]

# 2) Agrupar por Barrio x month. Tomamos mediana de precio_m2, counts y mediana superficie
group_cols = ["Barrio","month"]
panel = df.groupby(group_cols).agg(
    n_listings = ("Codigo","count"),
    precio_m2_med = ("precio_m2","median"),
    superficie_med = ("superficie_ref","median")
).reset_index()

# 3) Pivot para obtener series: filas=Barrio, columnas=month
pivot = panel.pivot(index="Barrio", columns="month", values="precio_m2_med")
print("Panel shape (barrio x month):", pivot.shape)
# Out:
# Panel shape (barrio x month): (3767, 82)

# %% [markdown]
# ### 6. ELIMINACIÓN DE OUTLIERS

# %%
def eliminar_outliers_por_mes(df, var="precio_m2", low_q=0.01, high_q=0.99):
    dfs = []
    for m, g in df.groupby("month"):
        low = g[var].quantile(low_q)
        high = g[var].quantile(high_q)
        gf = g[(g[var].isna()) | ((g[var] >= low) & (g[var] <= high))]
        dfs.append(gf)
    return pd.concat(dfs, ignore_index=True)

df_clean = eliminar_outliers_por_mes(df, "precio_m2", 0.01, 0.99)

# Reconstruir panel con df_clean
panel_clean = df_clean.groupby(["Barrio","month"]).agg(
    n_listings=("Codigo","count"),
    precio_m2_med=("precio_m2","median")
).reset_index()
pivot_clean = panel_clean.pivot(index="Barrio", columns="month", values="precio_m2_med")

# %%
min_coverage = 0.6  # exigir 60% de meses con dato
valid_series = pivot_clean.index[(pivot_clean.notna().mean(axis=1) >= min_coverage)].tolist()
pivot_final = pivot_clean.loc[valid_series]
print("Series válidas (Barrio):", len(pivot_final))
# Out:
# Series válidas (Barrio): 1229

# %%
pivot_imputed = pivot_final.copy().T  # months x barrios for interpolation
pivot_imputed = pivot_imputed.interpolate(method="linear", limit_direction="both", axis=0)
pivot_imputed = pivot_imputed.fillna(method="ffill").fillna(method="bfill")
pivot_imputed = pivot_imputed.T  # barrios x months

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_ts = scaler.fit_transform(pivot_imputed.values)  # cada fila es una serie
# Reshape para tslearn: (n_series, time_len, 1)
X_ts3 = X_ts.reshape((X_ts.shape[0], X_ts.shape[1], 1))

# %% [markdown]
# ### 7. CLUSTERING DTW — PRIMER NIVEL

# %%
# Calcular matriz de distancias DTW (opcional: solo para silhouette)
# ADVERTENCIA: cdist_dtw puede ser costoso si hay muchas series.
dist_matrix = cdist_dtw(X_ts3.squeeze())  # shape (n_series, n_series)

# Función para probar varios k y calcular silhouette (usa dist_matrix precomputada)
def silhouette_dtw(dist_matrix, labels):
    # silhouette_score acepta metric='precomputed' when you pass distance matrix and labels
    return silhouette_score(dist_matrix, labels, metric="precomputed")

from sklearn.cluster import KMeans

results_k = []
K_RANGE = range(2,9)
for k in K_RANGE:
    km_dtw = TimeSeriesKMeans(n_clusters=k, metric="dtw", max_iter=20, random_state=0)
    labels_k = km_dtw.fit_predict(X_ts3)
    sil = silhouette_dtw(dist_matrix, labels_k)
    results_k.append((k, sil))
    print("k=",k,"silhouette (DTW):", sil)

# Elegir k con mayor silhouette
best_k = max(results_k, key=lambda x: x[1])[0]
print("Best k (primer nivel):", best_k)
# Out:
# k= 2 silhouette (DTW): 0.5744296215258585
# k= 3 silhouette (DTW): 0.47777972802451996
# k= 4 silhouette (DTW): 0.40798761371467746
# k= 5 silhouette (DTW): 0.3688846728629175
# k= 6 silhouette (DTW): 0.22363051155971836
# k= 7 silhouette (DTW): 0.17313347620148584
# k= 8 silhouette (DTW): 0.20717364806158914
# Best k (primer nivel): 2

# %%
model_lvl1 = TimeSeriesKMeans(n_clusters=best_k, metric="dtw", max_iter=50, random_state=0)
labels_lvl1 = model_lvl1.fit_predict(X_ts3)
pivot_imputed["cluster_lvl1"] = labels_lvl1

# %%
time_index = pivot_imputed.columns[:-1]  # months
plt.figure(figsize=(10,6))
for i in range(best_k):
    prototype = model_lvl1.cluster_centers_[i].squeeze()
    plt.plot(prototype, label=f"Cluster {i}")
plt.legend()
plt.title("Prototipos DTW - Nivel 1 (precio m2)")
plt.xlabel("Meses (orden temporal)")
plt.ylabel("precio_m2 (estandarizado)")
plt.show()

# %% [markdown]
# ### 8. CLUSTERING DTW — SEGUNDO NIVEL

# %%
subcluster_labels = {}
for c in np.unique(labels_lvl1):
    idx = np.where(labels_lvl1 == c)[0]
    X_sub = X_ts3[idx]
    if len(idx) < 3:
        subcluster_labels[c] = np.zeros(len(idx), dtype=int)
        continue
    # elegir k_sub (por ejemplo 2 o probar con silhouette)
    k_sub = 2
    model_sub = TimeSeriesKMeans(n_clusters=k_sub, metric="dtw", max_iter=50, random_state=0)
    labels_sub = model_sub.fit_predict(X_sub)
    subcluster_labels[c] = labels_sub
    print(f"Cluster {c} -> subclusters: {np.unique(labels_sub)}")
# Out:
# Cluster 0 -> subclusters: [0 1]
# Cluster 1 -> subclusters: [0 1]

# %% [markdown]
# #### Estrategia B (clusterizar los prototipos del nivel1 si querés agrupar clusters similares):

# %%
# Centroides nivel 1: shape (best_k, time_len, 1)
centroids = model_lvl1.cluster_centers_
# reclusterizar estos centroides en K2 grupos (ej K2=3)
K2 = 3
model_lvl2 = TimeSeriesKMeans(n_clusters=K2, metric="dtw", max_iter=50, random_state=0)
labels_lvl2 = model_lvl2.fit_predict(centroids)
print("Labels nivel2 para cada prototipo nivel1:", labels_lvl2)
# Out:
# Labels nivel2 para cada prototipo nivel1: [0 1]

# %% [markdown]
# ### 9. EVALUACIÓN Y MÉTRICAS

# %%
# Tamaño
import collections
count_by_cluster = collections.Counter(labels_lvl1)
print("Tamaños nivel 1:", count_by_cluster)

# Evolución promedio por cluster (prototipos ya estandarizados)
for i in range(best_k):
    plt.plot(model_lvl1.cluster_centers_[i].squeeze(), label=f"Cluster {i}")
plt.legend(); plt.title("Evolución promedio (prototipos)"); plt.show()
# Out:
# Tamaños nivel 1: Counter({0: 1146, 1: 83})

# %% [markdown]
# ### 10. GUARDAR RESULTADOS / TABLAS PARA PRESENTACIÓN

# %%
# DataFrame con barrio, cluster y stats
# Partimos del pivot_imputed ya armado
df_clusters = pivot_imputed.reset_index()

# Asegurarnos de que la primera columna sea 'Barrio'
# (sea cual sea el nombre que tenía el índice)
if df_clusters.columns[0] != "Barrio":
    df_clusters.rename(columns={df_clusters.columns[0]: "Barrio"}, inplace=True)

# Asegurar que cluster_lvl1 existe y es int
if "cluster_lvl1" not in df_clusters.columns:
    raise ValueError("❌ La columna 'cluster_lvl1' no existe en pivot_imputed / df_clusters.")

df_clusters["cluster_lvl1"] = df_clusters["cluster_lvl1"].astype(int)

# 🔍 Columnas de serie temporal = todas excepto Barrio y cluster_lvl1
cols_serie = [c for c in df_clusters.columns if c not in ["Barrio", "cluster_lvl1"]]

if not cols_serie:
    raise ValueError("❌ No se encontraron columnas para la serie temporal (cols_serie está vacío).")

# Aseguramos que esas columnas sean numéricas
df_clusters[cols_serie] = df_clusters[cols_serie].apply(
    pd.to_numeric, errors="coerce"
)

def slope(series: pd.Series):
    """
    Slope (pendiente) de una serie temporal usando regresión lineal simple.
    `series` es un pandas.Series numérico (puede tener NaN).
    """
    arr = series.to_numpy(dtype="float64")
    x = np.arange(len(arr))

    mask = ~np.isnan(arr)
    if mask.sum() < 2:
        return np.nan

    m, b = np.polyfit(x[mask], arr[mask], 1)
    return m

stats_by_barrio = []
for _, row in df_clusters.iterrows():
    # Solo columnas numéricas de la serie temporal
    serie = row[cols_serie]

    stats_by_barrio.append({
        "Barrio": row["Barrio"],
        "cluster_lvl1": row["cluster_lvl1"],
        "mean_pr": np.nanmean(serie.to_numpy(dtype="float64")),
        "slope_pr": slope(serie)
    })

df_stats_barrio = pd.DataFrame(stats_by_barrio)

# Resumen por cluster
resumen_clusters = (
    df_stats_barrio
    .groupby("cluster_lvl1")
    .agg(
        n_barrios=("Barrio", "count"),      # cuántos barrios por cluster
        mediana_mean_pr=("mean_pr", "median"),
        mediana_slope_pr=("slope_pr", "median"),
    )
)

resumen_clusters.to_csv("cluster_summary.csv", index=True)
print("✅ cluster_summary.csv generado correctamente")
# Out:
# ✅ cluster_summary.csv generado correctamente
