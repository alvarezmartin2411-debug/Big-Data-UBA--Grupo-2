# %% [markdown]
# **MAESTRÍA EN ECONOMÍA APLICADA - UBA 2025**
# **TALLER DE PROGRAMACIÓN**
# **GRUPO 2**

# %% [markdown]
# # PROYECTO FINAL: TALLER DE PROGRAMACIÓN

# %%
# En caso no contar con las librerías, instalar con el siguiente cod
# !pip install pandas numpy scipy scikit-learn tslearn hdbscan matplotlib seaborn geopandas folium plotly openpyxl tqdm

# %% [markdown]
# ### 1) IMPORTS + CONFIGURACIÓN GENERAL

# %%
import os, glob, warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
from datetime import datetime
from tqdm import tqdm

# Preproc y ML
from sklearn.preprocessing import StandardScaler
from sklearn.impute import KNNImputer
from sklearn.metrics import silhouette_score
from scipy import stats
from pathlib import Path

# DTW / clustering
from tslearn.clustering import TimeSeriesKMeans
from tslearn.metrics import cdist_dtw

# Visualización
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")

# %%
# BASE_PATH = r"C:\Users\marti\Downloads\Bases"  # ajustá si hace falta
BASE_PATH = Path(r"D:\Maestría UBA\Semestre 5\Taller de programacion\Bases")
START_YEAR = 2019
END_YEAR = 2025

# %%
for year in range(START_YEAR, END_YEAR + 1):
    year_path = BASE_PATH / str(year)
    if not year_path.is_dir():
        print(f"⚠️ Carpeta año {year} no existe, se salta.")
        continue

    # Buscar carpetas tipo StockArgenprop_*
    for carpeta in year_path.glob("StockArgenprop_*"):
        if not carpeta.is_dir():
            continue

        # Rutas relevantes
        parquet_file = carpeta / "StockArgenprop.parquet"

        # 🔍 Si ya existe parquet → saltar carpeta
        if parquet_file.exists():
            print(f"⏩ Parquet ya existe, se ignora: {parquet_file}")
            continue

        # Buscar Excel
        xlsx_files = list(carpeta.glob("StockArgenprop*.xlsx"))
        if not xlsx_files:
            print(f"⚠️ No se encontró StockArgenprop*.xlsx en {carpeta}")
            continue

        excel_file = xlsx_files[0]

        print(f"📂 Leyendo Excel: {excel_file}")
        try:
            df = pd.read_excel(excel_file, engine="openpyxl")
        except Exception as e:
            print(f"❌ Error leyendo {excel_file}: {e}")
            continue

        print(f"   📊 Excel leído correctamente: {df.shape[0]} filas.")

        print(f"💾 Guardando como parquet: {parquet_file}")
        try:
            df.to_parquet(parquet_file, index=False)
            print("   ✅ Parquet generado correctamente.\n")
        except Exception as e:
            print(f"   ❌ Error guardando parquet: {e}\n")
# Out:
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2019\StockArgenprop_2019-01-31\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2019\StockArgenprop_2019-02-28\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2019\StockArgenprop_2019-03-31\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2019\StockArgenprop_2019-04-30\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2019\StockArgenprop_2019-05-31\StockArgenprop.parquet
# ⏩ Parquet ya existe, se ignora: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2019\StockArgenprop_2019-06-30\StockArgenprop.parquet
# ...

# %% [markdown]
# ### 2) FUNCIONES PARA CARGA DE BASES MENSUALES

# %%
dfs = []

for year in range(START_YEAR, END_YEAR + 1):
    year_path = BASE_PATH / str(year)
    if not year_path.is_dir():
        continue

    for carpeta in year_path.glob("StockArgenprop_*"):
        parquet_file = carpeta / "StockArgenprop.parquet"
        if parquet_file.is_file():
            print(f"📂 Leyendo parquet: {parquet_file}")
            df = pd.read_parquet(parquet_file)
            df["ArchivoOrigen"] = parquet_file.name
            dfs.append(df)

if not dfs:
    raise ValueError("No se encontraron archivos parquet. Ejecuta primero la conversión de Excel.")

df_raw = pd.concat(dfs, ignore_index=True)
print("📊 Total archivos cargados:", len(dfs))
print("📊 Total filas concatenadas:", df_raw.shape[0])
# Out:
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2019\StockArgenprop_2019-01-31\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2019\StockArgenprop_2019-02-28\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2019\StockArgenprop_2019-03-31\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2019\StockArgenprop_2019-04-30\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2019\StockArgenprop_2019-05-31\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2019\StockArgenprop_2019-06-30\StockArgenprop.parquet
# 📂 Leyendo parquet: D:\Maestría UBA\Semestre 5\Taller de programacion\Bases\2019\StockArgenprop_2019-07-31\StockArgenprop.parquet
# ...

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34485350 entries, 0 to 34485349
# Data columns (total 27 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   Codigo                    object
#  1   FechaPublicacion          object
#  2   FechaModificacion         object
#  3   Pais                      object
#  4   Provincia                 object
#  5   Localidad                 object
#  6   Barrio                    object
#  7   SubBarrio                 object
#  8   TipoPropiedad             object
#  9   TipoOperacion             object
#  10  Calle                     object
#  11  Numero                    float64
#  12  Piso                      object
#  13  Departamento              object
#  14  Latitud                   object
#  15  Longitud                  object
#  16  Nombre                    object
#  17  MontoOperacion            float64
#  18  PropiedadSuperficieTotal  object
# ...

# %% [markdown]
# ### 3) LIMPIEZA + GENERACIÓN DE VARIABLES

# %%
def limpiar_y_generar(df: pd.DataFrame) -> pd.DataFrame:
    """
    Limpia y enriquece el DataFrame de propiedades:
    - Normaliza nombres de columnas (strip).
    - Asegura tipos de fechas y numéricos (solo cuando hace falta).
    - Crea columna 'month' usando FechaModificacion (fallback FechaPublicacion).
    - Crea 'superficie_ref', 'precio_m2' y 'log_precio_m2'.
    - Filtra a registros en dólares y MontoOperacion != 0.
    - Asegura que superficie_ref sea positiva y no nula.
    - Normaliza 'Codigo' como string.
    - Descarta 'CantidadAmbientes'.
    - Aplica controles a 'CantidadDormitorios' para uso en clustering.
    - Filtra periodo desde START_YEAR.
    - Filtra solo TipoOperacion = 'Venta'.

    ⚠️ Modifica el DataFrame EN EL LUGAR (in-place) y lo devuelve.
    """

    # 1) Normalizar nombres de columnas (quitar espacios al inicio/fin)
    cols_map = {c: c.strip() for c in df.columns}
    df.rename(columns=cols_map, inplace=True)

    # 2) Fechas: solo convertir si no son datetime64[ns]
    for col in ["FechaPublicacion", "FechaModificacion"]:
        if col in df.columns and not np.issubdtype(df[col].dtype, np.datetime64):
            df[col] = pd.to_datetime(df[col], errors="coerce")

    # 3) month: usar FechaModificacion cuando exista, si no FechaPublicacion
    if "FechaModificacion" in df.columns and "FechaPublicacion" in df.columns:
        base_fecha = df["FechaModificacion"].fillna(df["FechaPublicacion"])
        df["month"] = base_fecha.dt.to_period("M")
    elif "FechaModificacion" in df.columns:
        df["month"] = df["FechaModificacion"].dt.to_period("M")
    elif "FechaPublicacion" in df.columns:
        df["month"] = df["FechaPublicacion"].dt.to_period("M")
    else:
        df["month"] = pd.PeriodIndex([pd.NaT] * len(df), freq="M")

    # 4) Variables numéricas: solo si la columna existe y no es ya numérica
    num_cols = [
        "MontoOperacion", "PropiedadSuperficieTotal", "SuperficieCubierta",
        "SuperficieDescubierta", "CantidadAmbientes", "CantidadDormitorios",
        "Antiguedad", "DepartamentoExpensas", "CantidadCocheras",
        "Latitud", "Longitud"
    ]
    for c in num_cols:
        if c in df.columns and not np.issubdtype(df[c].dtype, np.number):
            df[c] = pd.to_numeric(df[c], errors="coerce")

    # 5) Filtrar a registros en dólares y MontoOperacion != 0
    if "Nombre" in df.columns and "MontoOperacion" in df.columns:
        mask = (df["Nombre"] == "Dolares") & (df["MontoOperacion"] != 0)
        df.drop(index=df.index[~mask], inplace=True)

    # 6) superficie_ref = PropiedadSuperficieTotal; si NaN, usar SuperficieCubierta
    if "PropiedadSuperficieTotal" in df.columns and "SuperficieCubierta" in df.columns:
        df["superficie_ref"] = df["PropiedadSuperficieTotal"].where(
            df["PropiedadSuperficieTotal"].notna(),
            df["SuperficieCubierta"]
        )
    elif "PropiedadSuperficieTotal" in df.columns:
        df["superficie_ref"] = df["PropiedadSuperficieTotal"]
    elif "SuperficieCubierta" in df.columns:
        df["superficie_ref"] = df["SuperficieCubierta"]
    else:
        df["superficie_ref"] = np.nan  # fallback extremo

    # 7) superficie_ref no debe ser negativa ni cero → solo marcar como NaN, no borrar fila
    df.loc[df["superficie_ref"] <= 0, "superficie_ref"] = np.nan
    # 👉 ya NO hacemos: df.dropna(subset=["superficie_ref"], inplace=True)

    # 8) precio_m2 = MontoOperacion / superficie_ref
    if "MontoOperacion" in df.columns:
        df["precio_m2"] = df["MontoOperacion"] / df["superficie_ref"]
        df.loc[(df["precio_m2"] <= 0) | (~np.isfinite(df["precio_m2"])), "precio_m2"] = np.nan
    else:
        df["precio_m2"] = np.nan

    # 9) log_precio_m2 = log(precio_m2) solo para valores > 0
    df["log_precio_m2"] = np.nan
    mask_precio = df["precio_m2"] > 0
    df.loc[mask_precio, "log_precio_m2"] = np.log(df.loc[mask_precio, "precio_m2"])

    # 10) Normalizar Codigo como string
    if "Codigo" in df.columns:
        df["Codigo"] = df["Codigo"].astype(str)

    # 11) Descartar variable CantidadAmbientes
    df.drop(columns=["CantidadAmbientes"], inplace=True, errors="ignore")

    # 12) Control para CantidadDormitorios (pensando en clustering)
    if "CantidadDormitorios" in df.columns:
        df.loc[df["CantidadDormitorios"] <= 0, "CantidadDormitorios"] = np.nan
        df.loc[df["CantidadDormitorios"] > 10, "CantidadDormitorios"] = np.nan

    # 13) Filtrar periodo seleccionado (ejemplo 2019-01 en adelante)
    df = df[df["month"].notna()]
    df = df[df["month"] >= pd.Period(f"{START_YEAR}-01", freq="M")]

    # 14) Filtrar solo operaciones de venta
    if "TipoOperacion" in df.columns:
        df = df[df["TipoOperacion"] == "Venta"]

    return df

# Uso:
df = limpiar_y_generar(df_raw)

# %%
# % de vacios
total_filas = len(df)

resumen_na = pd.DataFrame({
    "n_na": df.isna().sum(),
    "%_na": df.isna().sum() / total_filas * 100
})

# Opcional: ordenar por % de NaN descendente
resumen_na = resumen_na.sort_values("%_na", ascending=False)

print(resumen_na)
# Out:
#                               n_na       %_na
# SubBarrio                 27416024  94.678275
# Piso                      25994066  89.767697
# Departamento              25950904  89.618641
# DepartamentoExpensas      21466767  74.133159
# CantidadCocheras          20285065  70.052279
# PropiedadSuperficieTotal  18328816  63.296584
# SuperficieDescubierta     15759543  54.423878
# Numero                    15397436  53.173381
# Barrio                    13732551  47.423880
# Antiguedad                12366370  42.705922
# SuperficieCubierta        11996315  41.427977
# CantidadDormitorios        9771181  33.743717
# log_precio_m2              8122444  28.049982
# precio_m2                  8122444  28.049982
# superficie_ref             8121464  28.046598
# Longitud                   6528494  22.545448
# Latitud                    6528494  22.545448
# Calle                       648706   2.240236
# MontoOperacion                1503   0.005190
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 28957038 entries, 10 to 34485349
# Data columns (total 30 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   Codigo                    object
#  1   FechaPublicacion          datetime64[ns]
#  2   FechaModificacion         datetime64[ns]
#  3   Pais                      object
#  4   Provincia                 object
#  5   Localidad                 object
#  6   Barrio                    object
#  7   SubBarrio                 object
#  8   TipoPropiedad             object
#  9   TipoOperacion             object
#  10  Calle                     object
#  11  Numero                    float64
#  12  Piso                      object
#  13  Departamento              object
#  14  Latitud                   float64
#  15  Longitud                  float64
#  16  Nombre                    object
#  17  MontoOperacion            float64
#  18  PropiedadSuperficieTotal  float64
# ...

# %% [markdown]
# ### 4. ESTADÍSTICA DESCRIPTIVA

# %%
# 1) Definir variables foco para clustering
features_clustering = ["log_precio_m2", "precio_m2", "superficie_ref", "CantidadDormitorios"]

# 2) Estadística básica global (con percentiles extra)
desc_global = (
    df[features_clustering]
    .describe(percentiles=[0.01, 0.05, 0.25, 0.5, 0.75, 0.95, 0.99])
    .T
)

# Agregar métricas de calidad de datos
desc_global["n_non_missing"] = df[features_clustering].notna().sum().values
desc_global["missing_pct"] = df[features_clustering].isna().mean().values

# 3) Conteos por mes (tamaño de muestra mensual)
conteo_mes = (
    df.groupby("month")
    .size()
    .rename("n_obs")
    .reset_index()
)

# 4) Descriptivos por mes para las variables principales del clustering
desc_by_month = (
    df.groupby("month")[features_clustering]
    .agg(["count", "mean", "median", "std"])
)

# 5) Distribución por TipoPropiedad (conteo y alguna estadística clave)
if "TipoPropiedad" in df.columns:
    tipo_prop_counts = (
        df["TipoPropiedad"]
        .value_counts()
        .reset_index()
        .rename(columns={"index": "TipoPropiedad", "TipoPropiedad": "count"})
    )

    # Opcional: agregar medianas de log_precio_m2 y superficie_ref por tipo
    tipo_prop_stats = (
        df.groupby("TipoPropiedad")[features_clustering]
        .agg(["count", "mean", "median"])
    )
else:
    tipo_prop_counts = pd.DataFrame()
    tipo_prop_stats = pd.DataFrame()

# 6) Precio_m2 por barrio (top 20, robusto)
if "Barrio" in df.columns and "precio_m2" in df.columns:
    precio_barrio = (
        df[df["precio_m2"].notna()]
        .groupby("Barrio")
        .agg(
            med_precio_m2=("precio_m2", "median"),
            n=("precio_m2", "size")
        )
        .query("n >= 200")  # mínimo de avisos por barrio (ajusta a gusto)
        .sort_values("med_precio_m2", ascending=False)
        .head(20)
    )
else:
    precio_barrio = pd.DataFrame()

# 7) Exportar a CSV
desc_global.to_csv("desc_global_clustering.csv")
conteo_mes.to_csv("conteo_mes.csv", index=False)
tipo_prop_counts.to_csv("tipo_prop_counts.csv", index=False)
tipo_prop_stats.to_csv("tipo_prop_stats.csv")
precio_barrio.to_csv("precio_barrio_top20.csv")
desc_by_month.to_csv("desc_by_month_clustering.csv")

# %% [markdown]
# ### 5-6. CONSTRUIR PANEL MENSUAL y ELIMINACIÓN DE OUTLIERS

# %%
# 1) Filtro de periodo + columnas relevantes
df_panel = df[df["month"].notna()].copy()
df_panel = df_panel[df_panel["month"] >= pd.Period(f"{START_YEAR}-01", freq="M")]

cols_needed = [
    "Barrio", "month", "Codigo",
    "precio_m2", "log_precio_m2", "superficie_ref"
]
cols_existing = [c for c in cols_needed if c in df_panel.columns]
df_panel = df_panel[cols_existing]

# Quitar filas sin barrio
df_panel = df_panel[df_panel["Barrio"].notna()]

# 2) Agregando mediana de log precios y nunique para codigos
group_cols = ["Barrio", "month"]

agg_dict = {
    "Codigo": ("Codigo", "nunique"),
    "precio_m2": ("precio_m2", "median"),
    "superficie_ref": ("superficie_ref", "median"),
}

if "log_precio_m2" in df_panel.columns:
    agg_dict["log_precio_m2"] = ("log_precio_m2", "median")

panel = (
    df_panel
    .groupby(group_cols)
    .agg(**agg_dict)
    .rename(columns={
        "Codigo": "n_listings",
        "precio_m2": "precio_m2_med",
        "log_precio_m2": "log_precio_m2_med",
        "superficie_ref": "superficie_med"
    })
    .reset_index()
)

# 3) Filtrar barrio-mes con muy pocos avisos
MIN_LISTINGS = 20
panel = panel[panel["n_listings"] >= MIN_LISTINGS]

# 4) Wide: barrio x month con log_precio_m2_med (mejor para clustering)
pivot_log = panel.pivot(index="Barrio", columns="month", values="log_precio_m2_med")

# Si por alguna razón no tuvieras log, usa precio_m2_med
if pivot_log.isna().all().all():  # todo NaN
    pivot_log = panel.pivot(index="Barrio", columns="month", values="precio_m2_med")

# Fijar rango completo de meses como columnas (orden temporal consistente)
all_months = pd.period_range(
    start=f"{START_YEAR}-01",
    end=panel["month"].max(),
    freq="M"
)
pivot_log = pivot_log.reindex(columns=all_months)

print("Panel shape (barrio x month):", pivot_log.shape)

# 5) Cobertura temporal por barrio (qué % de meses tiene dato)
coverage = pivot_log.notna().mean(axis=1).rename("coverage")

# Nos quedamos con barrios que tienen datos en al menos 70% de los meses
min_coverage = 0.7
barrios_keep = coverage[coverage >= min_coverage].index

pivot_log_filtered = pivot_log.loc[barrios_keep]
print("Panel filtrado (barrio x month):", pivot_log_filtered.shape)

# 6) Imputación temporal: interpolación a lo largo del tiempo (por barrio)
# Ordenamos columnas por mes por seguridad (ya deberían estar, pero reforzamos)
pivot_imputed = pivot_log_filtered.copy()
pivot_imputed = pivot_imputed.sort_index(axis=1)  # columnas = meses ordenados

# Guardamos el índice para mapear luego los clusters a barrios
series_index = pivot_imputed.index  # lista de barrios en el mismo orden que X_ts3

# Transponer: ahora filas = meses, columnas = barrios (para interpolar en el eje del tiempo)
pivot_imputed_T = pivot_imputed.T

pivot_imputed_T = pivot_imputed_T.interpolate(
    method="linear",
    limit_direction="both",
    axis=0
)

# Completar cualquier NaN residual con forward/backward fill
pivot_imputed_T = pivot_imputed_T.fillna(method="ffill").fillna(method="bfill")

# Volvemos a formato barrios x meses
pivot_imputed = pivot_imputed_T.T

# 7) Escalado para clustering (cada columna/mes con media 0, varianza 1)
X = pivot_imputed.values.astype(float)  # shape: (n_barrios, n_meses)

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# 8) Preparar formato para tslearn: (n_series, time_len, 1)
X_ts3 = X_scaled.reshape((X_scaled.shape[0], X_scaled.shape[1], 1))

# 9) Guardar insumos útiles
panel.to_csv("panel_barrio_month_long.csv", index=False)
pivot_log_filtered.to_csv("panel_barrio_month_logprecio_wide.csv")
pivot_imputed.to_csv("panel_barrio_month_logprecio_imputed.csv")
coverage.to_csv("coverage_por_barrio.csv")
# Out:
# Panel shape (barrio x month): (851, 82)
# Panel filtrado (barrio x month): (197, 82)

# %% [markdown]
# ### 7. CLUSTERING DTW — PRIMER NIVEL

# %%
# Calcular matriz de distancias DTW (opcional: solo para silhouette)
# ADVERTENCIA: cdist_dtw puede ser costoso si hay muchas series.
dist_matrix = cdist_dtw(X_ts3.squeeze())  # shape (n_series, n_series)

# Función para probar varios k y calcular silhouette (usa dist_matrix precomputada)
def silhouette_dtw(dist_matrix, labels):
    # silhouette_score acepta metric='precomputed' when you pass distance matrix and labels
    return silhouette_score(dist_matrix, labels, metric="precomputed")

from sklearn.cluster import KMeans

results_k = []
K_RANGE = range(2,9)
for k in K_RANGE:
    km_dtw = TimeSeriesKMeans(n_clusters=k, metric="dtw", max_iter=20, random_state=0)
    labels_k = km_dtw.fit_predict(X_ts3)
    sil = silhouette_dtw(dist_matrix, labels_k)
    results_k.append((k, sil))
    print("k=",k,"silhouette (DTW):", sil)

# Elegir k con mayor silhouette
best_k = max(results_k, key=lambda x: x[1])[0]
print("Best k (primer nivel):", best_k)
# Out:
# k= 2 silhouette (DTW): 0.5557002041800765
# k= 3 silhouette (DTW): 0.40343701268078075
# k= 4 silhouette (DTW): 0.39470468027836497
# k= 5 silhouette (DTW): 0.4085737486273487
# k= 6 silhouette (DTW): 0.3196996112041185
# k= 7 silhouette (DTW): 0.2695089220650818
# k= 8 silhouette (DTW): 0.30764488954418295
# Best k (primer nivel): 2

# %%
model_lvl1 = TimeSeriesKMeans(n_clusters=best_k, metric="dtw", max_iter=50, random_state=0)
labels_lvl1 = model_lvl1.fit_predict(X_ts3)
pivot_imputed["cluster_lvl1"] = labels_lvl1

# %%
time_index = pivot_imputed.columns[:-1]  # months
plt.figure(figsize=(10,6))
for i in range(best_k):
    prototype = model_lvl1.cluster_centers_[i].squeeze()
    plt.plot(prototype, label=f"Cluster {i}")
plt.legend()
plt.title("Prototipos DTW - Nivel 1 (precio m2)")
plt.xlabel("Meses (orden temporal)")
plt.ylabel("precio_m2 (estandarizado)")
plt.show()

# %% [markdown]
# #### 7.1. Tabla de barrios por cluster con geografía

# %%
# 1.1. DataFrame de asignación de cluster a nivel barrio
cluster_barrio = pd.DataFrame({
    "Barrio": series_index,
    "cluster_lvl1": labels_lvl1
})

# 1.2. Extraer info geográfica por barrio desde df (a nivel aviso)
geo_cols = [c for c in ["Barrio", "Provincia", "Localidad", "Latitud", "Longitud"] if c in df.columns]

geo_barrio = (
    df[geo_cols]
    .dropna(subset=["Barrio"])
    .groupby("Barrio")
    .agg({
        "Provincia": "first" if "Provincia" in geo_cols else "first",
        "Localidad": "first" if "Localidad" in geo_cols else "first",
        "Latitud": "median" if "Latitud" in geo_cols else "first",
        "Longitud": "median" if "Longitud" in geo_cols else "first",
    })
    .reset_index()
)

# 1.3. Cruzar barrios + cluster + geografía
cluster_geo = cluster_barrio.merge(geo_barrio, on="Barrio", how="left")

# 1.4. Tablas de conteo por Provincia y Localidad
if "Provincia" in cluster_geo.columns:
    ct_prov = pd.crosstab(cluster_geo["Provincia"], cluster_geo["cluster_lvl1"])
    ct_prov_pct = ct_prov.div(ct_prov.sum(axis=1), axis=0)  # % por provincia
    ct_prov.to_csv("cluster_geografia_provincia_counts.csv")
    ct_prov_pct.to_csv("cluster_geografia_provincia_pct.csv")

if "Localidad" in cluster_geo.columns:
    ct_loc = pd.crosstab(cluster_geo["Localidad"], cluster_geo["cluster_lvl1"])
    ct_loc_pct = ct_loc.div(ct_loc.sum(axis=1), axis=0)     # % por localidad
    ct_loc.to_csv("cluster_geografia_localidad_counts.csv")
    ct_loc_pct.to_csv("cluster_geografia_localidad_pct.csv")

# Guardar listado de barrios con cluster y geografía
cluster_geo.to_csv("barrios_cluster_lvl1_geografia.csv", index=False)

# %% [markdown]
# #### 7.2. Nivel de precios y dinamicas

# %%
# 2.1. Añadir cluster al panel (Barrio–month)
panel_clust = panel.merge(cluster_barrio, on="Barrio", how="inner").copy()

# 2.2. Año a partir de la PeriodIndex "month"
panel_clust["year"] = panel_clust["month"].dt.year

# 2.3. Estadísticas anuales por cluster
precio_year = (
    panel_clust
    .groupby(["cluster_lvl1", "year"])
    .agg(
        med_precio_m2=("precio_m2_med", "median"),
        med_log_precio_m2=("log_precio_m2_med", "median"),
        n_obs=("precio_m2_med", "size")
    )
    .reset_index()
)

precio_year.to_csv("precio_m2_cluster_por_anio.csv", index=False)

# 2.4. (Opcional) Índice base 100 en START_YEAR para comparar trayectorias
START_YEAR = int(panel_clust["year"].min())

base = (
    precio_year[precio_year["year"] == START_YEAR]
    .set_index("cluster_lvl1")["med_precio_m2"]
)

precio_year = precio_year.merge(
    base.rename("base_precio_m2"),
    on="cluster_lvl1",
    how="left"
)

precio_year["indice_base_100"] = 100 * precio_year["med_precio_m2"] / precio_year["base_precio_m2"]

precio_year.to_csv("precio_m2_cluster_indice_base100.csv", index=False)

# %% [markdown]
# #### 7.3. Características estructurales por cluster

# %%
# 3.1.1. Resumen de características a nivel barrio-month por cluster
struct_panel = (
    panel_clust
    .groupby("cluster_lvl1")
    .agg(
        med_superficie_med=("superficie_med", "median"),
        mean_superficie_med=("superficie_med", "mean"),
        med_n_listings=("n_listings", "median"),
        mean_n_listings=("n_listings", "mean")
    )
    .reset_index()
)

struct_panel.to_csv("caracteristicas_panel_por_cluster.csv", index=False)

# %%
# 3.2.1. Merge a nivel aviso
df_clust = df.merge(cluster_barrio, on="Barrio", how="inner")

# 3.2.2. Crear indicadores útiles (si existen las columnas)
if "CantidadCocheras" in df_clust.columns:
    df_clust["tiene_cochera"] = df_clust["CantidadCocheras"].fillna(0) > 0
else:
    df_clust["tiene_cochera"] = False

# 3.2.3. Agregar estadísticas estructurales por cluster
agg_struct = {
    "superficie_ref": ["median", "mean"],
    "CantidadDormitorios": ["median", "mean"],
    "Antiguedad": ["median", "mean"],
    "tiene_cochera": ["mean"],
}

# Filtrar a columnas existentes
agg_struct = {k: v for k, v in agg_struct.items() if k in df_clust.columns}

struct_listings = (
    df_clust
    .groupby("cluster_lvl1")
    .agg(agg_struct)
)

# Aplanar MultiIndex de columnas
struct_listings.columns = [
    f"{col[0]}_{col[1]}" for col in struct_listings.columns.to_flat_index()
]
struct_listings = struct_listings.reset_index()

struct_listings.to_csv("caracteristicas_estructurales_por_cluster.csv", index=False)

# %% [markdown]
# ### 8. CLUSTERING DTW — SEGUNDO NIVEL

# %% [markdown]
# #### Estrategia A (sub–clustering dentro de cada cluster):

# %%
subcluster_labels = {}
sub_models = {}

for c in np.unique(labels_lvl1):
    idx = np.where(labels_lvl1 == c)[0]
    X_sub = X_ts3[idx]
    if len(idx) < 10:   # por ejemplo, exigir al menos 10 barrios
        subcluster_labels[c] = np.zeros(len(idx), dtype=int)
        continue

    k_sub = 2  # o probar 2–3 y evaluar silhouette dentro del grupo
    model_sub = TimeSeriesKMeans(
        n_clusters=k_sub,
        metric="dtw",
        max_iter=50,
        random_state=0
    )
    labels_sub = model_sub.fit_predict(X_sub)
    subcluster_labels[c] = labels_sub
    sub_models[c] = model_sub
    print(f"Cluster {c} -> subclusters: {np.unique(labels_sub)}")
# Out:
# Cluster 0 -> subclusters: [0 1]
# Cluster 1 -> subclusters: [0 1]

# %% [markdown]
# ##### Aplanamos subcluster_labels a un vector global

# %%
# labels_lvl1: array (n_barrios,) del clustering DTW nivel 1
# series_index: índice de barrios en el mismo orden que X_ts3 / labels_lvl1
# subcluster_labels: dict {cluster_padre -> array de sublabels dentro de ese cluster}
k_sub = 2  # el número de subclusters que usaste

# 1) Vector global de subclusters (mismo orden que labels_lvl1)
sub_labels_global = np.empty_like(labels_lvl1)

for c in np.unique(labels_lvl1):
    idx = np.where(labels_lvl1 == c)[0]
    labels_sub_c = subcluster_labels[c]   # array de tamaño len(idx)
    sub_labels_global[idx] = labels_sub_c

# 2) Construir DataFrame con la jerarquía de clusters por barrio
df_clusters_hier = pd.DataFrame({
    "Barrio": series_index,
    "cluster_lvl1": labels_lvl1,
    "subcluster_lvl2": sub_labels_global
})

# 3) Identificador global de cluster de segundo nivel (0..3 si k_sub=2)
df_clusters_hier["cluster_lvl2"] = df_clusters_hier["cluster_lvl1"] * k_sub + df_clusters_hier["subcluster_lvl2"]

# (Opcional) etiqueta legible tipo "1_0"
df_clusters_hier["cluster_lvl2_str"] = (
    df_clusters_hier["cluster_lvl1"].astype(str)
    + "_" +
    df_clusters_hier["subcluster_lvl2"].astype(str)
)

df_clusters_hier.to_csv("barrios_clusters_nivel1_nivel2_DTWA.csv", index=False)

# %%
# Añadimos a la matriz temporal pivot_imputed
# pivot_imputed: DataFrame (n_barrios x n_meses) con log_precio_m2 imputado
pivot_imputed_with_clusters = pivot_imputed.copy()

# Aseguramos que el índice es barrio
# (si no lo es, ajusta este paso)
pivot_imputed_with_clusters = pivot_imputed_with_clusters.merge(
    df_clusters_hier.set_index("Barrio")[["cluster_lvl1", "subcluster_lvl2", "cluster_lvl2"]],
    left_index=True,
    right_index=True,
    how="left"
)

pivot_imputed_with_clusters.to_csv("panel_temporal_imputed_clusters_nivel2_DTWA.csv")

# %%
# Añadimos al panel largo
panel_lvl2 = panel.merge(
    df_clusters_hier[["Barrio", "cluster_lvl1", "subcluster_lvl2", "cluster_lvl2"]],
    on="Barrio",
    how="left"
)

panel_lvl2.to_csv("panel_barrio_month_nivel2_DTWA.csv", index=False)

# %%
# Vemos los prototipos de los subclusters

for c, model_sub in sub_models.items():
    plt.figure(figsize=(10, 6))
    for s in range(k_sub):
        proto = model_sub.cluster_centers_[s].squeeze()
        plt.plot(proto, label=f"Cluster padre {c} – Subcluster {s}")
    plt.title(f"Prototipos DTW – Nivel 2 dentro del cluster padre {c}")
    plt.xlabel("Meses (orden temporal)")
    plt.ylabel("precio_m2 (estandarizado)")
    plt.legend()
    plt.show()

# %%
# ============================================================
# 1) Cruce con geografía (por cluster de 2º nivel)
# ============================================================

# 1.1. DataFrame con cluster_lvl2 por barrio
# (si aún no lo tienes cargado, lee desde CSV: df_clusters_hier = pd.read_csv("barrios_clusters_nivel1_nivel2_DTWA.csv"))
cluster_barrio_lvl2 = df_clusters_hier[["Barrio", "cluster_lvl2"]].copy()

# 1.2. Info geográfica por barrio (Provincia, Localidad, Lat/Long si existen)
geo_cols = [c for c in ["Barrio", "Provincia", "Localidad", "Latitud", "Longitud"] if c in df.columns]

geo_barrio = (
    df[geo_cols]
    .dropna(subset=["Barrio"])
    .groupby("Barrio")
    .agg({
        "Provincia": "first" if "Provincia" in geo_cols else "first",
        "Localidad": "first" if "Localidad" in geo_cols else "first",
        "Latitud": "median" if "Latitud" in geo_cols else "first",
        "Longitud": "median" if "Longitud" in geo_cols else "first",
    })
    .reset_index()
)

# 1.3. Cruzar barrios + cluster2 + geografía
cluster2_geo = cluster_barrio_lvl2.merge(geo_barrio, on="Barrio", how="left")

# Tablas de conteo por Provincia y Localidad
if "Provincia" in cluster2_geo.columns:
    ct_prov_2 = pd.crosstab(cluster2_geo["Provincia"], cluster2_geo["cluster_lvl2"])
    ct_prov_2_pct = ct_prov_2.div(ct_prov_2.sum(axis=1), axis=0)
    ct_prov_2.to_csv("cluster2_geografia_provincia_counts.csv")
    ct_prov_2_pct.to_csv("cluster2_geografia_provincia_pct.csv")

if "Localidad" in cluster2_geo.columns:
    ct_loc_2 = pd.crosstab(cluster2_geo["Localidad"], cluster2_geo["cluster_lvl2"])
    ct_loc_2_pct = ct_loc_2.div(ct_loc_2.sum(axis=1), axis=0)
    ct_loc_2.to_csv("cluster2_geografia_localidad_counts.csv")
    ct_loc_2_pct.to_csv("cluster2_geografia_localidad_pct.csv")

cluster2_geo.to_csv("barrios_cluster2_geografia.csv", index=False)


# ============================================================
# 2) Niveles y dinámica de precios (por cluster2)
# ============================================================

# 2.1. Añadir clusters al panel (Barrio–month)
panel_lvl2 = panel.merge(
    df_clusters_hier[["Barrio", "cluster_lvl2"]],
    on="Barrio",
    how="inner"
).copy()

# 2.2. Extraer año desde month (Period[M])
panel_lvl2["year"] = panel_lvl2["month"].dt.year

# 2.3. Estadísticas anuales de precio por m² por cluster2
precio_year_2 = (
    panel_lvl2
    .groupby(["cluster_lvl2", "year"])
    .agg(
        med_precio_m2=("precio_m2_med", "median"),
        med_log_precio_m2=("log_precio_m2_med", "median"),
        n_obs=("precio_m2_med", "size")
    )
    .reset_index()
)

precio_year_2.to_csv("precio_m2_cluster2_por_anio.csv", index=False)

# 2.4. Índice base 100 en el primer año observado, por cluster2
START_YEAR = int(panel_lvl2["year"].min())

base_2 = (
    precio_year_2[precio_year_2["year"] == START_YEAR]
    .set_index("cluster_lvl2")["med_precio_m2"]
)

precio_year_2 = precio_year_2.merge(
    base_2.rename("base_precio_m2"),
    on="cluster_lvl2",
    how="left"
)

precio_year_2["indice_base_100"] = 100 * precio_year_2["med_precio_m2"] / precio_year_2["base_precio_m2"]

precio_year_2.to_csv("precio_m2_cluster2_indice_base100.csv", index=False)


# ============================================================
# 3) Características estructurales (por cluster2)
# ============================================================

# 3.1. Resumen a partir del panel (superficie, n_listings)
struct_panel_2 = (
    panel_lvl2
    .groupby("cluster_lvl2")
    .agg(
        med_superficie_med=("superficie_med", "median"),
        mean_superficie_med=("superficie_med", "mean"),
        med_n_listings=("n_listings", "median"),
        mean_n_listings=("n_listings", "mean")
    )
    .reset_index()
)

struct_panel_2.to_csv("caracteristicas_panel_por_cluster2.csv", index=False)

# 3.2. Resumen a nivel aviso, cruzando df con cluster2
df_clust2 = df.merge(
    df_clusters_hier[["Barrio", "cluster_lvl2"]],
    on="Barrio",
    how="inner"
)

# Indicador de cochera (si existe la columna)
if "CantidadCocheras" in df_clust2.columns:
    df_clust2["tiene_cochera"] = df_clust2["CantidadCocheras"].fillna(0) > 0
else:
    df_clust2["tiene_cochera"] = False

# Diccionario de agregaciones estructurales
agg_struct_2 = {
    "superficie_ref": ["median", "mean"],
    "CantidadDormitorios": ["median", "mean"],
    "Antiguedad": ["median", "mean"],
    "tiene_cochera": ["mean"],
}

# Filtrar solo variables presentes
agg_struct_2 = {k: v for k, v in agg_struct_2.items() if k in df_clust2.columns}

struct_listings_2 = (
    df_clust2
    .groupby("cluster_lvl2")
    .agg(agg_struct_2)
)

# Aplanar MultiIndex de columnas
struct_listings_2.columns = [
    f"{col[0]}_{col[1]}" for col in struct_listings_2.columns.to_flat_index()
]
struct_listings_2 = struct_listings_2.reset_index()

struct_listings_2.to_csv("caracteristicas_estructurales_por_cluster2.csv", index=False)

# %% [markdown]
# #### Estrategia B (clusterizar los prototipos del nivel1 si querés agrupar clusters similares):

# %%
subcluster_labels = {}
for c in np.unique(labels_lvl1):
    idx = np.where(labels_lvl1 == c)[0]
    X_sub = X_ts3[idx]
    if len(idx) < 3:
        subcluster_labels[c] = np.zeros(len(idx), dtype=int)
        continue
    # elegir k_sub (por ejemplo 2 o probar con silhouette)
    k_sub = 2
    model_sub = TimeSeriesKMeans(n_clusters=k_sub, metric="dtw", max_iter=50, random_state=0)
    labels_sub = model_sub.fit_predict(X_sub)
    subcluster_labels[c] = labels_sub
    print(f"Cluster {c} -> subclusters: {np.unique(labels_sub)}")
# Out:
# Cluster 0 -> subclusters: [0 1]
# Cluster 1 -> subclusters: [0 1]

# %%
# Centroides nivel 1: shape (best_k, time_len, 1)
centroids = model_lvl1.cluster_centers_
# reclusterizar estos centroides en K2 grupos (ej K2=3)
K2 = 3
model_lvl2 = TimeSeriesKMeans(n_clusters=K2, metric="dtw", max_iter=50, random_state=0)
labels_lvl2 = model_lvl2.fit_predict(centroids)
print("Labels nivel2 para cada prototipo nivel1:", labels_lvl2)
# Out:
# Labels nivel2 para cada prototipo nivel1: [0 1]

# %% [markdown]
# ### 9. EVALUACIÓN Y MÉTRICAS

# %%
# Tamaño
import collections
count_by_cluster = collections.Counter(labels_lvl1)
print("Tamaños nivel 1:", count_by_cluster)

# Evolución promedio por cluster (prototipos ya estandarizados)
for i in range(best_k):
    plt.plot(model_lvl1.cluster_centers_[i].squeeze(), label=f"Cluster {i}")
plt.legend(); plt.title("Evolución promedio (prototipos)"); plt.show()
# Out:
# Tamaños nivel 1: Counter({1: 105, 0: 17})

# %% [markdown]
# ### 10. GUARDAR RESULTADOS / TABLAS PARA PRESENTACIÓN

# %%
# DataFrame con barrio, cluster y stats
# Partimos del pivot_imputed ya armado
df_clusters = pivot_imputed.reset_index()

# Asegurarnos de que la primera columna sea 'Barrio'
# (sea cual sea el nombre que tenía el índice)
if df_clusters.columns[0] != "Barrio":
    df_clusters.rename(columns={df_clusters.columns[0]: "Barrio"}, inplace=True)

# Asegurar que cluster_lvl1 existe y es int
if "cluster_lvl1" not in df_clusters.columns:
    raise ValueError("❌ La columna 'cluster_lvl1' no existe en pivot_imputed / df_clusters.")

df_clusters["cluster_lvl1"] = df_clusters["cluster_lvl1"].astype(int)

# 🔍 Columnas de serie temporal = todas excepto Barrio y cluster_lvl1
cols_serie = [c for c in df_clusters.columns if c not in ["Barrio", "cluster_lvl1"]]

if not cols_serie:
    raise ValueError("❌ No se encontraron columnas para la serie temporal (cols_serie está vacío).")

# Aseguramos que esas columnas sean numéricas
df_clusters[cols_serie] = df_clusters[cols_serie].apply(
    pd.to_numeric, errors="coerce"
)

def slope(series: pd.Series):
    """
    Slope (pendiente) de una serie temporal usando regresión lineal simple.
    `series` es un pandas.Series numérico (puede tener NaN).
    """
    arr = series.to_numpy(dtype="float64")
    x = np.arange(len(arr))

    mask = ~np.isnan(arr)
    if mask.sum() < 2:
        return np.nan

    m, b = np.polyfit(x[mask], arr[mask], 1)
    return m

stats_by_barrio = []
for _, row in df_clusters.iterrows():
    # Solo columnas numéricas de la serie temporal
    serie = row[cols_serie]

    stats_by_barrio.append({
        "Barrio": row["Barrio"],
        "cluster_lvl1": row["cluster_lvl1"],
        "mean_pr": np.nanmean(serie.to_numpy(dtype="float64")),
        "slope_pr": slope(serie)
    })

df_stats_barrio = pd.DataFrame(stats_by_barrio)

# Resumen por cluster
resumen_clusters = (
    df_stats_barrio
    .groupby("cluster_lvl1")
    .agg(
        n_barrios=("Barrio", "count"),      # cuántos barrios por cluster
        mediana_mean_pr=("mean_pr", "median"),
        mediana_slope_pr=("slope_pr", "median"),
    )
)

resumen_clusters.to_csv("cluster_summary.csv", index=True)
print("✅ cluster_summary.csv generado correctamente")
# Out:
# ✅ cluster_summary.csv generado correctamente
