# %% [markdown]
# **MAESTRÍA EN ECONOMÍA APLICADA - UBA 2025**
# **TALLER DE PROGRAMACIÓN**
# **GRUPO 2**

# %%
# Carga de usuario para simplificar paths de acceso según quién ejecute el código
print("Ingrese su número de referencia de usuario de la lista\nAlvarez - 1\nGodino - 2\nSulca - 3\nOtro usuario - 4:")
usuario = input("Ingrese su número de referencia de usuario de la lista\nAlvarez - 1\nGodino - 2\nSulca - 3\nOtro usuario - 4:")
if usuario == '1':
    nombre = "Alvarez"
    path = "C:\\Users\\marti\\OneDrive\\Documentos\\"
elif usuario == '2':
    nombre = "Alvarez"
    path = "C:\\Users\\Usuario\\Documents\\"
elif usuario == '3':
    nombre = "Alvarez"
    path = "C:\\Users\\user\\Documents\\"
elif usuario == '4':
    print("A modo de ejemplo, el path a la carpeta Github debe tener esta forma: C:\\Users\\Usuario\\Documents\\")
    path = input("Ingrese el path en su computadora a la carpeta Github: ")
print(f"Path cargado correctamente")
# Out:
# Ingrese su número de referencia de usuario de la lista
# Alvarez - 1
# Godino - 2
# Sulca - 3
# Otro usuario - 4:
# Ingrese su número de referencia de usuario de la lista
# Alvarez - 1
# Godino - 2
# Sulca - 3
# Otro usuario - 4: 3
# Path cargado correctamente

# %% [markdown]
# # PROYECTO FINAL: TALLER DE PROGRAMACIÓN

# %%
# Librerías a utilizar
# !pip install openpyxl - utilizar en caso no te cargue el archivo de excel
import pandas as pd
import numpy as np
import seaborn as sns   
import matplotlib.pyplot as plt

# %%
# Carga de datos
bd = pd.read_excel(path+"GitHub\\Big-Data-UBA--Grupo-2\\Proyecto Final\\bd.xlsx")

# %%
# Revisamos la data
bd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545639 entries, 0 to 545638
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Codigo                    545639 non-null  object
#  1   FechaPublicacion          545639 non-null  object
#  2   FechaModificacion         545639 non-null  object
#  3   Pais                      545639 non-null  object
#  4   Provincia                 545639 non-null  object
#  5   Localidad                 545639 non-null  object
#  6   Barrio                    271698 non-null  object
#  7   SubBarrio                 23987 non-null   object
#  8   TipoPropiedad             545639 non-null  object
#  9   TipoOperacion             545639 non-null  object
#  10  Calle                     524218 non-null  object
#  11  Numero                    253236 non-null  float64
#  12  Piso                      68117 non-null   object
#  13  Departamento              30593 non-null   object
#  14  Latitud                   532836 non-null  float64
#  15  Longitud                  532836 non-null  float64
#  16  Nombre                    541446 non-null  object
#  17  MontoOperacion            541382 non-null  float64
#  18  PropiedadSuperficieTotal  261322 non-null  float64
#  19  SuperficieCubierta        371834 non-null  float64
#  20  SuperficieDescubierta     249119 non-null  float64
#  21  CantidadAmbientes         111 non-null     float64
#  22  CantidadDormitorios       377658 non-null  float64
#  23  Antiguedad                306321 non-null  float64
#  24  DepartamentoExpensas      175590 non-null  float64
#  25  CantidadCocheras          162797 non-null  float64
# dtypes: float64(12), object(14)
# memory usage: 108.2+ MB

# %%
# Revisamos la data
bd.describe()
# Out:
#              Numero        Latitud       Longitud  MontoOperacion  \
# count  2.532360e+05  532836.000000  532836.000000    5.413820e+05
# mean   3.397218e+04     -33.920783     -58.376580    5.031335e+05
# std    5.718598e+06       4.868341       7.453200    1.354725e+07
# min   -5.100000e+01     -88.051570    -180.000000    0.000000e+00
# 25%    4.560000e+02     -34.703583     -58.898851    6.000000e+04
# 50%    1.300000e+03     -34.594530     -58.519802    1.200000e+05
# 75%    2.736000e+03     -34.370750     -58.389299    2.470000e+05
# max    1.700101e+09      85.116930      81.909910    2.147484e+09
#
#        PropiedadSuperficieTotal  SuperficieCubierta  SuperficieDescubierta  \
# count              2.613220e+05        3.718340e+05           2.491190e+05
# mean               3.396690e+05        4.243674e+02           9.886271e+01
# std                9.476249e+07        1.822523e+05           5.037535e+03
# min                0.000000e+00       -4.000000e+00          -1.000000e+02
# 25%                5.800000e+01        4.500000e+01           0.000000e+00
# 50%                1.700000e+02        7.370000e+01           1.000000e+00
# 75%                5.250000e+02        1.380000e+02           3.500000e+01
# max                3.800000e+10        1.111111e+08           2.119200e+06
#
#        CantidadAmbientes  CantidadDormitorios    Antiguedad  \
# count         111.000000        377658.000000  3.063210e+05
# mean            2.693694             2.110100  1.376204e+02
# std             1.204482             1.359472  1.980779e+03
# min             1.000000             0.000000 -1.049969e+06
# 25%             2.000000             1.000000  0.000000e+00
# 50%             2.000000             2.000000  1.400000e+01
# 75%             3.000000             3.000000  4.000000e+01
# max             8.000000            50.000000  1.111110e+05
#
#        DepartamentoExpensas  CantidadCocheras
# count          1.755900e+05     162797.000000
# mean           1.230597e+05          0.452435
# std            9.021229e+06          1.764615
# min            0.000000e+00         -2.000000
# 25%            0.000000e+00          0.000000
# 50%            1.177500e+03          0.000000
# 75%            1.000000e+05          1.000000
# max            2.147484e+09        360.000000
